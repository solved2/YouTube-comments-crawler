# %% [markdown]
# # Selenium을 이용하여 유튜브 채널의 특정 댓글 추출하기
# - 2021.03.14 : 댓글(comment) 크롤링 구현
# - 2021.03.15 : 답글(reply) 크롤링 구현
# - 2021.03.16 : 답글 크롤링 디버그 + 자세히 보기 구현

# %% [markdown]
# ### 필요한 라이브러리 불러오기

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains

# %% [markdown]
# ### 설정값

# %%
# 목표 채널의 '동영상' 카테고리 url
channel = "https://www.youtube.com/channel/UCwkGvF7xKz2E0Lv-fZ9wv2g/videos"

# 콘텐츠 로딩 대기 시간
long_waiting = 2.0
short_waiting = 1.0

# %% [markdown]
# ### 원하는 유튜브 채널의 '동영상' 카테고리에서 모든 영상 url 크롤링

# %%
driver = webdriver.Chrome('chromedriver.exe')
driver.get(channel)
href = []
# 현재 화면의 높이를 구한다.
last_height = driver.execute_script("return document.documentElement.scrollHeight")
while True:
    # 스크롤을 맨 아래까지 내린다.
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # 콘텐츠 로딩 시간을 기다린다.
    time.sleep(short_wating)

    # 현재 높이와 이전 높이값을 비교한다(더 스크롤할 지를 검사)
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

videos = driver.find_elements_by_id('video-title')

# 테스트 목적으로 5개의 영상만 크롤링.
num = 5
for video in videos:
    href += [video.get_attribute('href')]
    if len(href) >= num:
        break

# %% [markdown]
# ### 각 영상에 접근하여 원하는 키워드를 포함한 댓글 크롤링

# %%
last_height = driver.execute_script("return document.documentElement.scrollHeight")
i = 0
# 채널의 각 영상에 접근한다.
for url in href:
    driver.get(url)
    print(f"Access the video of {i}")
    time.sleep(long_waiting)
    # 댓글창이 화면에 보일 때까지 적당히 스크롤(버퍼링 오작동 방지)
    driver.execute_script("window.scrollTo(0, 500);")
    time.sleep(long_waiting)
    # 모든 댓글을 크롤링 할 수 있도록 무한 스크롤
    while True:
        driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
        time.sleep(long_waiting)
        new_height = driver.execute_script("return document.documentElement.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
        
    comments_area = driver.find_elements_by_css_selector('#contents > ytd-comment-thread-renderer')
    find = False
    # 각 영상의 원하는 댓글을 추출한다.
    for comment_area in comments_area:
        comment = comment_area.find_element_by_css_selector('#comment').text
        # 목적에 맞는 댓글일 경우
        if "?" in comment:
            find = True
            actions = ActionChains(driver)
            actions.move_to_element(comment_area).perform()
            time.sleep(short_waiting)
            repliy_area = comment_area.find_element_by_css_selector('#replies')
            # 답글이 있는 댓글인지를 검사
            try:
                button = repliy_area.find_element_by_css_selector('#button > yt-icon')
                # 답글 보기 버튼을 클릭
                button.click()
                time.sleep(long_waiting)
            except:
                pass
            # '자세히 보기'가 있으면 모두 클릭
            try:
                long_texts = comment_area.find_elements_by_css_selector('#more > span')
                for long_text in long_texts:
                    long_text.click()
                    time.sleep(short_waiting)
            except:
                pass
            # 모든 답글 크롤링
            replies = repliy_area.find_elements_by_css_selector('#content-text')
            print(f"Comment block : \n{comment}")
            for reply in replies:
                print(f"  └ {reply.text}")
    # 댓글을 한 개 이상 찾았을 경우 해당 영상의 url 출력
    if find:
        print(f"url : {url}")
    i+=1

driver.close()
# Out:
# Access the video of 0
# Comment block :
# 최창현
# 4개월 전
# 좋은 책 감사합니다 ㅎㅎ 고생 많으셨습니다! 혹시 팡요랩의 향후 계획도 알 수 있을까요?!
# 4
# 답글
#   └ 제가 개인적인 사정으로 너무 바빠서.. 유튜브 활동을 못하고 있네요 하하..
# url : https://www.youtube.com/watch?v=Sq-JOue82QA
# Access the video of 1
# Comment block :
# Jongwon Kim
# 1년 전
# 발표자료는 공개해 주실수 없나요?
# 답글
# Comment block :
# 김평
# 1시간 전
# 먼저 좋은 강의 감사드립니다~
# 강의 슬라이드는 혹시 어디서 찾을수 있을까요?
# 답글
# url : https://www.youtube.com/watch?v=6Thu5vlDc6Y
# Access the video of 2
# Comment block :
# J.S BACH
# 9개월 전
# 팡요랩 계속해주시면 안되나요?ㅠㅠ
# 답글
# Comment block :
# 우체국택배
# 1년 전
# 이번주 목요일 T 아카데미 교육 참석 신청했습니다^^ 책은 언제쯤 출간 목표이신가요??
# 1
# 답글
# Comment block :
# 이영준
# 1년 전
# 책출시일이 언제인가요??
# 답글
# url : https://www.youtube.com/watch?v=d6OX6KjhPVE
# Access the video of 3
# Comment block :
# 강동구
# 3개월 전
# 영상 잘봤습니다. 올려주신 코드 돌려보니까 policy가 수렴하지 않는거 같은데, 이유가 뭔지 알려주실수 있나요?
# 1
# 답글
# Comment block :
# 양민규
# 1년 전
# 혹시 SAC 나 TD3 에 대한 논문리뷰 나 구현시리즈는
# 해주실수 없을까요?
# 염치 없지만 정말 큰도움 받고 있습니다 !
# 답글
# Comment block :
# hyokyun an
# 1년 전
# 강의 정말 감사합니다!! 그런데 깃헙에서 코드를 보면 K_epoch이 왜 있는지 잘 이해가 안갑니다.. 같은 데이터로 K_epoch번 업데이트하는 것으로 이해했는데 제 이해가 맞나요? 만약 맞다면 그냥 lr을 K_poch배 해준 것과 비슷한 효과 아닌가요? 물론 K_epoch번 업데이트하는 동안 파라미터가 조금씩 바뀌어서 lr를 정확히 K_epoch배 한 것과 같지는 않겠지만 하나의 데이터로 여러번 학습하는 것은 되려 variance가 높아지지 않을까요?..
# 자세히 보기
# 답글
# Comment block :
# HyeonChul Jung
# 1년 전
# Policy 네트워크와 value 네트워크가 파라미터를 공유하고 있는데 저렇게 학습하면 공유하고 있는 파라미터만 업데이트되는 건가요? 아니면 순수 value 네트워크 파라미터도 업데이트 되는 건가요??
# 답글
# Comment block :
# 韓範洙
# 6개월 전
# 좋은 영상 정말 감사합니다. 연구에 많은 도움이 되었습니다. 실내용 네비게이션 로봇제어를 하고 있는데요, 설명해주신 PPO 코드를 참고하여 만들어서 돌려본 결과, 제대로 목표 지점까지 잘 가지만, 24,000 틱 까지는 reward가 단조감소 하다가 증가하는 추세를 보이고 있는데요. 보상 히스토리 대로라면 학습이 잘 안 되야 맞는데, 시뮬레이션 환경에서 로봇은 목표지점까지 잘 만 가고 있고 심지어 연속으로 성공하는 등 결과자체만 놓고 보면은 양호하게 나오고 있어요. 혹시 왜 이런 결과가 나오는지, 짐작가는 부분이 있으시다면 조언 부탁드려도 될까요? 그냥 단순히 제가 코드를 잘못짠것 일수도 있지만...ㅎ;;
# 자세히 보기
# 답글
# Comment block :
# Jeffrey Lim
# 1년 전
# 잘 되는 것 같다가도 잘 안되는데 저만 이럴까요..?
# # of episode :20, avg score : 35.4
# # of episode :40, avg score : 45.5
# # of episode :60, avg score : 88.8
# 자세히 보기
# 답글
# Comment block :
# Jeffrey Lim
# 1년 전(수정됨)
# softmax 에서 dim = None 해주시면 굳이 데이터 차원에 따라 0, 1 안넣어주셔도 항상 뜻하신대로 돌아가지 않을까요..?
# t_horizon 만큼의 데이터셋 하나를 1 rollout 이라고 하나요?
# 1
# 답글
# Comment block :
# keenranger
# 1년 전
# 24:55 쯤에 내용이 헷갈려서 여쭤봅니다. 한 batch로 트레인을 할 때 prob_a가 바뀌지 않는 것은 알겠는데, 다음 batch때는 그 batch에 의해 prob_a가 업데이트된 것을 확인하고 그 후 pi와의 차를 구하는 게 아닌가요???
# 답글
# Comment block :
# 강경웅
# 1년 전
# 안녕하세요. github에 존재하는 PPO-lstm 코드 부분에 대해서 질문 드리고 싶은데요.. make_batch() function에서 리턴값이 h_in_lst[0], h_out_lst[0] 이렇게 hidden state 값을 0번째 인덱스만 주게끔 되어있는데, 이러면 다른 1, 2, 3, 4, .... batch_size 까지의 hidden state는 사용하지 않는 건가요? 코드를 참고하며 직접 구현해보다가 잘 학습이 되질 않아서, 윗부분과 연관이 있을 거 같아서 질문 드립니다!
# 자세히 보기
# 답글
# Comment block :
# Jeffrey Lim
# 1년 전(수정됨)
# 4:00 if done: break 가 어떤 의미를 갖는지 좀 더 설명해주실 수 있을까요? 저는 이 코드 snippent 은 없어도 그만이라고 생각했습니다. 12번째 step 까지 진행되다가 게임이 종료되면  기존에는12개의 frame 으로만 train 을 했을 것입니다. 그런데, break 가 없으면 12개의 frame 에 새로운게임 frame 8 개가 추가되서 총 20개의 frame 으로 train 할 것입니다. 그런데 어차피 모델 입장에서는 frame 이 몇개든 각각의 frame 에 대응하는 action 을 할 뿐이니 if done: break 가 없어도 괜찮을 것 같기도 합니다. 실제로 다른 PPO 구현 (
# 자세히 보기
# 1
# 답글
# url : https://www.youtube.com/watch?v=l1CZQWBkdcY
# Access the video of 4
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-41-614b33152bb1> in <module>
#       7     time.sleep(long_waiting)
#       8     # 댓글창이 화면에 보일 때까지 적당히 스크롤(버퍼링 오작동 방지)
# ----> 9     driver.execute_script("window.scrollTo(0, 500);")
#      10     time.sleep(long_waiting)
#      11     # 모든 댓글을 크롤링 할 수 있도록 무한 스크롤
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=89.0.4389.90)
